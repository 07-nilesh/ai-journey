# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=yf.download("AAPL",period="6mo",interval="1d")
df["MA7"]=df["Close"].rolling(window=7).mean()
df["MA30"]=df["Close"].rolling(window=30).mean()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(12,5))
plt.plot(df.index,df["Close"],label="price",color="blue")
plt.plot(df.index,df["MA7"],label="7-day MA",color="orange")
plt.plot(df.index,df["MA30"],label="30-day MA",color="green")
plt.title("stock price with 7-day and 30 day Moving Averages")
plt.xlabel("Date")
plt.ylabel("price")
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["Daily_Return"]=df["Close"].pct_change()
df["Cumulative_Return"]=(1+df["Daily_Return"]).cumprod()
print(df[["Close", "Daily_Return", "Cumulative_Return"]].head(15))
# Out:
# Price            Close Daily_Return Cumulative_Return
# Ticker            AAPL
# Date
# 2026-02-17  263.409943          NaN               NaN
# 2026-02-18  263.879120     0.001781          1.001781
# 2026-02-19  260.115784    -0.014262          0.987494
# 2026-02-20  264.108673     0.015350          1.002653
# 2026-02-23  265.705811     0.006047          1.008716
# 2026-02-24  271.655243     0.022391          1.031302
# 2026-02-25  273.741516     0.007680          1.039222
# 2026-02-26  272.463776    -0.004668          1.034372
# 2026-02-27  263.709381    -0.032130          1.001137
# 2026-03-02  264.248413     0.002044          1.003183
# 2026-03-03  263.280182    -0.003664          0.999507
# 2026-03-04  262.052338    -0.004664          0.994846
# 2026-03-05  259.826324    -0.008495          0.986395
# 2026-03-06  257.001343    -0.010873          0.975671
# 2026-03-09  259.417053     0.009400          0.984842

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df["Cumulative_Return"], label="Cumulative Return", color="green")
plt.title("Cumulative Returns Over Time")
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.legend()
plt.grid(True)
plt.show()
