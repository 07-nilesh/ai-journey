# %%
import pandas as pd

# %%
pd.Series([40000,65000,60000],index=["A","B","C"])
pd.Series({"A":40000,"B":65000,"C":60000})
# Out:
# A    40000
# B    65000
# C    60000
# dtype: int64

# %%
pd.DataFrame({
    "name": ["Aman", "Riya"],
    "salary": [40000, 65000]
})
# Out:
#    name  salary
# 0  Aman   40000
# 1  Riya   65000

# %%
pd.DataFrame([
    {"name": "Aman", "salary": 40000},
    {"name": "Riya", "salary": 65000}
])
# Out:
#    name  salary
# 0  Aman   40000
# 1  Riya   65000

# %%
df=pd.read_csv("employees_100.csv")
df
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.head()
df.tail()
# Out:
#     employee_id         name department     city   age salary  experience  \
# 95          161  Nikhil Nair  MARKETING  Chennai  22.0  55740           0
# 96          172   Neha Desai         HR  Chennai  22.0  52250           0
# 97          115   Neha Reddy  Marketing  Chennai  43.0    NaN          12
# 98          193  Priya Nayak         HR      NaN  23.0  56821           3
# 99          152  Kavya Joshi  Marketing    Delhi  44.0  69499          10
#
#     performance_score  projects_completed joining_date
# 95                  5                  22   2020-04-22
# 96                  5                   7   2020-11-14
# 97                  4                  10   2019-06-06
# 98                  9                  16   2019-08-07
# 99                  7                   4   2022-03-25

# %%
df.sample()
# Out:
#     employee_id             name   department   city   age salary  experience  \
# 65          168  Sanjay Kulkarni  Engineering  Delhi  34.0  80358           7
#
#     performance_score  projects_completed joining_date
# 65                  5                  14   2020-04-01

# %%
df.shape
df.dtypes
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    object
#  2   department          92 non-null     object
#  3   city                90 non-null     object
#  4   age                 94 non-null     float64
#  5   salary              92 non-null     object
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 7.9+ KB
#        employee_id        age  experience  performance_score  \
# count   100.000000  94.000000  100.000000           100.0000
# mean    148.740000  30.861702    4.830000             5.7500
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'name', 'department', 'city', 'age', 'salary',
#        'experience', 'performance_score', 'projects_completed',
#        'joining_date'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df["salary"]
# Out:
# 0     70719
# 1     77058
# 2     69911
# 3     69993
# 4     88216
#       ...
# 95    55740
# 96    52250
# 97      NaN
# 98    56821
# 99    69499
# Name: salary, Length: 100, dtype: object

# %%
df[["name","salary"]]
# Out:
#               name salary
# 0     Swati Kapoor  70719
# 1   Kavya Malhotra  77058
# 2     Manish Desai  69911
# 3         Neha Das  69993
# 4        Isha Nair  88216
# ..             ...    ...
# 95     Nikhil Nair  55740
# 96      Neha Desai  52250
# 97      Neha Reddy    NaN
# 98     Priya Nayak  56821
# 99     Kavya Joshi  69499
#
# [100 rows x 2 columns]

# %%
df.set_index("employee_id")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.set_index("employee_id")
#
# File c:\Users\kashy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['employee_id'] are in the columns"

# %%
df
# Out:
#                        name    department       city   age salary  experience  \
# employee_id
# 184            Swati Kapoor  Data Science    Kolkata  38.0  70719           5
# 154          Kavya Malhotra   engineering     Mumbai   NaN  77058           1
# 171            Manish Desai  Data Science  Hyderabad  23.0  69911           0
# 146                Neha Das   Engineering       Pune  28.0  69993           3
# 145               Isha Nair  Data Science        NaN  32.0  88216           8
# ...                     ...           ...        ...   ...    ...         ...
# 161             Nikhil Nair     MARKETING    Chennai  22.0  55740           0
# 172              Neha Desai            HR    Chennai  22.0  52250           0
# 115              Neha Reddy     Marketing    Chennai  43.0    NaN          12
# 193             Priya Nayak            HR        NaN  23.0  56821           3
# 152             Kavya Joshi     Marketing      Delhi  44.0  69499          10
#
# ...

# %%
df.loc[184:145]
# Out:
#                        name    department       city   age salary  experience  \
# employee_id
# 184            Swati Kapoor  Data Science    Kolkata  38.0  70719           5
# 154          Kavya Malhotra   engineering     Mumbai   NaN  77058           1
# 171            Manish Desai  Data Science  Hyderabad  23.0  69911           0
# 146                Neha Das   Engineering       Pune  28.0  69993           3
# 145               Isha Nair  Data Science        NaN  32.0  88216           8
#
#              performance_score  projects_completed joining_date
# employee_id
# 184                          5                   6   2021-07-02
# 154                          8                   8   2024-02-05
# 171                          6                  18   2019-04-24
# 146                          8                   1   2022-12-13
# 145                          8                  14   2019-11-25

# %%
df.iloc[0:10]
# Out:
#                         name    department       city   age salary  \
# employee_id
# 184             Swati Kapoor  Data Science    Kolkata  38.0  70719
# 154           Kavya Malhotra   engineering     Mumbai   NaN  77058
# 171             Manish Desai  Data Science  Hyderabad  23.0  69911
# 146                 Neha Das   Engineering       Pune  28.0  69993
# 145                Isha Nair  Data Science        NaN  32.0  88216
# 140              Rahul Gupta         Sales  Hyderabad  23.0  52404
# 123               Sneha Iyer            HR  Hyderabad  33.0  59895
# 181                Karan Rao     Marketing        NaN  22.0  50733
# 111              Kavya Singh   Engineering      Delhi  23.0    NaN
# 101          Ananya Malhotra   engineering        NaN  24.0  68591
#
#              experience  performance_score  projects_completed joining_date
# employee_id
# 184                   5                  5                   6   2021-07-02
# ...

# %%
df.loc[154:145][["name","city","age"]]
# Out:
#                        name       city   age
# employee_id
# 154          Kavya Malhotra     Mumbai   NaN
# 171            Manish Desai  Hyderabad  23.0
# 146                Neha Das       Pune  28.0
# 145               Isha Nair        NaN  32.0

# %%
df[df["age"]>40]
# Out:
#                      name    department       city   age salary  experience  \
# employee_id
# 113             Ritu Nair       Finance        NaN  41.0  74778          10
# 179             Arjun Das       Finance        NaN  43.0    NaN          10
# 164           Sneha Gupta           NaN      Delhi  42.0  63209          11
# 155            Sanjay Das           NaN  Bangalore  45.0  74505          17
# 176          Shreya Menon       Finance        NaN  41.0  80597           9
# 164           Sneha Gupta           NaN      Delhi  42.0  63209          11
# 124          Deepak Verma  Data Science  Hyderabad  41.0  86380           9
# 115            Neha Reddy     Marketing    Chennai  43.0    NaN          12
# 152           Kavya Joshi     Marketing      Delhi  44.0  69499          10
#
#              performance_score  projects_completed joining_date
# employee_id
# 113                          7                   5   2018-02-13
# ...

# %%
df.columns
# Out:
# Index(['name', 'department', 'city', 'age', 'salary', 'experience',
#        'performance_score', 'projects_completed', 'joining_date'],
#       dtype='object')

# %%
df[(df["department"]=="Finance")&(df["age"]>30)]
# Out:
#                        name department       city   age  salary  experience  \
# employee_id
# 113               Ritu Nair    Finance        NaN  41.0   74778          10
# 112            Aditya Reddy    Finance        NaN  31.0   58811           2
# 179               Arjun Das    Finance        NaN  43.0     NaN          10
# 137               Ritu Bose    Finance  Bangalore  38.0   71062           8
# 180          Ashok Kulkarni    Finance    Kolkata  31.0   58777           3
# 176            Shreya Menon    Finance        NaN  41.0   80597           9
# 195              Pooja Nair    Finance        NaN  33.0   69396           6
# 160            Shreya Singh    Finance       Pune  38.0   62020           5
# 138             Rahul Gupta    Finance  Hyderabad  35.0  75,614          11
#
#              performance_score  projects_completed joining_date
# employee_id
# 113                          7                   5   2018-02-13
# ...

# %%
df[df["department"].isin(["Engineering","Data Science"])]
df[df["experience"].between(2,5)]
df[df["name"].str.contains("Verma")]
# Out:
#                      name    department       city   age  salary  experience  \
# employee_id
# 127          Suresh Verma  Data Science  Bangalore  27.0  72,862           2
# 116           Rohan Verma   Engineering    Chennai  23.0   62693           0
# 110           Arjun Verma     Marketing       Pune  29.0   62227           4
# 151           Sneha Verma       Finance      Delhi   NaN   66422           5
# 147           Tanvi Verma   Engineering  Bangalore  35.0   77217           8
# 133            Riya Verma            HR    Kolkata  26.0   59693           3
# 124          Deepak Verma  Data Science  Hyderabad  41.0   86380           9
# 188          Sanjay Verma            HR  Bangalore  33.0   59591           8
# 192           Divya Verma            HR      Delhi  40.0   66363          12
#
#              performance_score  projects_completed joining_date
# employee_id
# 127                          6                  10   2023-02-21
# ...

# %%
df[["salary"]]
# Out:
#             salary
# employee_id
# 184          70719
# 154          77058
# 171          69911
# 146          69993
# 145          88216
# ...            ...
# 161          55740
# 172          52250
# 115            NaN
# 193          56821
# 152          69499
#
# [100 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df2=df.dropna()

# %%
df2.isnull().sum()
# Out:
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df.dropna(subset=["city"])
# Out:
#                        name    department       city   age salary  experience  \
# employee_id
# 184            Swati Kapoor  Data Science    Kolkata  38.0  70719           5
# 154          Kavya Malhotra   engineering     Mumbai   NaN  77058           1
# 171            Manish Desai  Data Science  Hyderabad  23.0  69911           0
# 146                Neha Das   Engineering       Pune  28.0  69993           3
# 140             Rahul Gupta         Sales  Hyderabad  23.0  52404           0
# ...                     ...           ...        ...   ...    ...         ...
# 121              Ashok Shah  Data Science       Pune  31.0  75498           4
# 161             Nikhil Nair     MARKETING    Chennai  22.0  55740           0
# 172              Neha Desai            HR    Chennai  22.0  52250           0
# 115              Neha Reddy     Marketing    Chennai  43.0    NaN          12
# 152             Kavya Joshi     Marketing      Delhi  44.0  69499          10
#
# ...

# %%
df.head()
# Out:
#                        name    department       city   age salary  experience  \
# employee_id
# 184            Swati Kapoor  Data Science    Kolkata  38.0  70719           5
# 154          Kavya Malhotra   engineering     Mumbai   NaN  77058           1
# 171            Manish Desai  Data Science  Hyderabad  23.0  69911           0
# 146                Neha Das   Engineering       Pune  28.0  69993           3
# 145               Isha Nair  Data Science        NaN  32.0  88216           8
#
#              performance_score  projects_completed joining_date
# employee_id
# 184                          5                   6   2021-07-02
# 154                          8                   8   2024-02-05
# 171                          6                  18   2019-04-24
# 146                          8                   1   2022-12-13
# 145                          8                  14   2019-11-25

# %%
df["age"]=df["age"].fillna(df["age"].mean())

# %%
df["salary"]=df["salary"].str.replace(",","",regex=False)
df["salary"]=pd.to_numeric(df["salary"],errors="coerce")
df["salary"]=df["salary"].fillna(df["salary"].median())

# %%
df["salary"].dtype
# Out:
# dtype('float64')

# %%
df.isnull().sum()
# Out:
# name                   0
# department             8
# city                  10
# age                    0
# salary                 0
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df["department"].value_counts()
# Out:
# department
# HR              17
# Marketing       17
# Finance         16
# Engineering     14
# Data Science    10
# Sales            8
# engineering      3
#  HR              2
#  Marketing       1
#  Finance         1
# FINANCE          1
# SALES            1
# MARKETING        1
# Name: count, dtype: int64

# %%
df["department"]=df["department"].fillna(df["department"].mode()[0])

# %%
df["city"]=df["city"].fillna(df["city"].mode()[0])

# %%
df.isnull().sum()
# Out:
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
df=df.reset_index()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=["employee_id"]).sum()
# Out:
# 4

# %%
df.drop_duplicates(subset=["employee_id"],keep="first")
# Out:
#     employee_id            name    department       city        age   salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1           154  Kavya Malhotra   engineering     Mumbai  30.861702  77058.0
# 2           171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3           146        Neha Das   Engineering       Pune  28.000000  69993.0
# 4           145       Isha Nair  Data Science  Hyderabad  32.000000  88216.0
# ..          ...             ...           ...        ...        ...      ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.000000  55740.0
# 96          172      Neha Desai            HR    Chennai  22.000000  52250.0
# 97          115      Neha Reddy     Marketing    Chennai  43.000000  62969.5
# 98          193     Priya Nayak            HR  Hyderabad  23.000000  56821.0
# 99          152     Kavya Joshi     Marketing      Delhi  44.000000  69499.0
#
# ...

# %%
df["joining_date"]=pd.to_datetime(df["joining_date"])

# %%
df["joining_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    object
#  2   department          100 non-null    object
#  3   city                100 non-null    object
#  4   age                 100 non-null    float64
#  5   salary              100 non-null    float64
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 7.9+ KB

# %%
df["annual_salary"]=df["salary"]*12

# %%
df.head()
# Out:
#    employee_id            name    department       city        age   salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1          154  Kavya Malhotra   engineering     Mumbai  30.861702  77058.0
# 2          171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3          146        Neha Das   Engineering       Pune  28.000000  69993.0
# 4          145       Isha Nair  Data Science  Hyderabad  32.000000  88216.0
#
#    experience  performance_score  projects_completed joining_date  \
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25
#
#    annual_salary
# 0       848628.0
# 1       924696.0
# 2       838932.0
# 3       839916.0
# 4      1058592.0

# %%
def categorize(num):
    if num>5:
        return "Experienced candidate"
    elif num <= 5:
        return "Learner"

# %%
df["experience_status"]=df["experience"].apply(categorize)

# %%
df.head()
# Out:
#    employee_id            name    department       city        age   salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1          154  Kavya Malhotra   engineering     Mumbai  30.861702  77058.0
# 2          171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3          146        Neha Das   Engineering       Pune  28.000000  69993.0
# 4          145       Isha Nair  Data Science  Hyderabad  32.000000  88216.0
#
#    experience  performance_score  projects_completed joining_date  \
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25
#
#    annual_salary      experience_status
# 0       848628.0                Learner
# ...

# %%
#department_codes={"Engineering":"ENG","Marketing":"MKT","Finance":"FIN"}
#df["department_codes"]=df["department"].map(department_codes)

# %%
df_salary_sorted=df.sort_values(by="employee_id")

# %%
df["department"].unique()
# Out:
# array(['Data Science', 'engineering', 'Engineering', 'Sales', 'HR',
#        'Marketing', ' Marketing ', 'Finance', ' Finance ', ' HR ',
#        'FINANCE', 'SALES', 'MARKETING'], dtype=object)

# %%
df["department"]=df["department"].str.strip().str.title()

# %%
df["department"].unique()
# Out:
# array(['Data Science', 'Engineering', 'Sales', 'Hr', 'Marketing',
#        'Finance'], dtype=object)

# %%
df.sort_values(
    by=["department", "salary"],
    ascending=[True, False]
)
# Out:
#     employee_id              name    department       city   age   salary  \
# 4           145         Isha Nair  Data Science  Hyderabad  32.0  88216.0
# 88          124      Deepak Verma  Data Science  Hyderabad  41.0  86380.0
# 59          190        Swati Bose  Data Science     Mumbai  22.0  78465.0
# 24          170        Rahul Nair  Data Science    Kolkata  30.0  76425.0
# 54          109    Rohan Kulkarni  Data Science      Delhi  28.0  76267.0
# ..          ...               ...           ...        ...   ...      ...
# 48          163  Rahul Chatterjee         Sales    Kolkata  25.0  60015.0
# 17          178     Vikram Kapoor         Sales    Chennai  29.0  57858.0
# 44          128  Rohan Chatterjee         Sales     Mumbai  26.0  52862.0
# 38          136      Sanjay Mehta         Sales  Hyderabad  30.0  52573.0
# 5           140       Rahul Gupta         Sales  Hyderabad  23.0  52404.0
#
#     experience  performance_score  projects_completed joining_date  \
# ...

# %%
df["salary_rank"]=df["salary"].rank(ascending=False)

# %%
df
# Out:
#     employee_id            name    department       city        age   salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1           154  Kavya Malhotra   Engineering     Mumbai  30.861702  77058.0
# 2           171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3           146        Neha Das   Engineering       Pune  28.000000  69993.0
# 4           145       Isha Nair  Data Science  Hyderabad  32.000000  88216.0
# ..          ...             ...           ...        ...        ...      ...
# 95          161     Nikhil Nair     Marketing    Chennai  22.000000  55740.0
# 96          172      Neha Desai            Hr    Chennai  22.000000  52250.0
# 97          115      Neha Reddy     Marketing    Chennai  43.000000  62969.5
# 98          193     Priya Nayak            Hr  Hyderabad  23.000000  56821.0
# 99          152     Kavya Joshi     Marketing      Delhi  44.000000  69499.0
#
# ...

# %%
df.sort_values(by="salary_rank")
# Out:
#     employee_id              name    department       city   age   salary  \
# 75          158    Tanvi Malhotra            Hr     Mumbai  32.0  88366.0
# 74          158    Tanvi Malhotra            Hr     Mumbai  32.0  88366.0
# 4           145         Isha Nair  Data Science  Hyderabad  32.0  88216.0
# 88          124      Deepak Verma  Data Science  Hyderabad  41.0  86380.0
# 84          102       Rahul Menon   Engineering  Hyderabad  38.0  84870.0
# ..          ...               ...           ...        ...   ...      ...
# 7           181         Karan Rao     Marketing  Hyderabad  22.0  50733.0
# 67          169  Swati Chatterjee            Hr       Pune  33.0  49801.0
# 33          129       Ashok Gupta     Marketing  Hyderabad  22.0  49693.0
# 36          167    Meera Malhotra            Hr  Hyderabad  31.0  48822.0
# 26          141   Manish Kulkarni            Hr    Chennai  27.0  45835.0
#
#     experience  performance_score  projects_completed joining_date  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=["employee_id"]).sum()
# Out:
# 4

# %%
df.drop_duplicates(subset=["employee_id"], keep="first",inplace=True)

# %%
df
# Out:
#     employee_id            name    department       city        age   salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1           154  Kavya Malhotra   Engineering     Mumbai  30.861702  77058.0
# 2           171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3           146        Neha Das   Engineering       Pune  28.000000  69993.0
# 4           145       Isha Nair  Data Science  Hyderabad  32.000000  88216.0
# ..          ...             ...           ...        ...        ...      ...
# 95          161     Nikhil Nair     Marketing    Chennai  22.000000  55740.0
# 96          172      Neha Desai            Hr    Chennai  22.000000  52250.0
# 97          115      Neha Reddy     Marketing    Chennai  43.000000  62969.5
# 98          193     Priya Nayak            Hr  Hyderabad  23.000000  56821.0
# 99          152     Kavya Joshi     Marketing      Delhi  44.000000  69499.0
#
# ...

# %%
df.nlargest(5, "salary")
# Out:
#     employee_id            name    department       city   age   salary  \
# 74          158  Tanvi Malhotra            Hr     Mumbai  32.0  88366.0
# 4           145       Isha Nair  Data Science  Hyderabad  32.0  88216.0
# 88          124    Deepak Verma  Data Science  Hyderabad  41.0  86380.0
# 84          102     Rahul Menon   Engineering  Hyderabad  38.0  84870.0
# 39          117  Pooja Malhotra   Engineering    Kolkata  24.0  84255.0
#
#     experience  performance_score  projects_completed joining_date  \
# 74          11                  5                  19   2021-02-26
# 4            8                  8                  14   2019-11-25
# 88           9                  7                   8   2024-06-05
# 84          11                  6                  15   2021-06-07
# 39           1                  8                  19   2021-12-05
#
#     annual_salary      experience_status  salary_rank
# 74      1060392.0  Experienced candidate          1.5
# ...

# %%
df["age"]=df["age"].astype(int)

# %%
df.groupby("city")["age"].mean()
# Out:
# city
# Bangalore    33.500000
# Chennai      29.400000
# Delhi        33.000000
# Hyderabad    30.892857
# Kolkata      28.000000
# Mumbai       27.666667
# Pune         31.642857
# Name: age, dtype: float64

# %%
df.groupby(["city","department"])["salary"].mean()
# Out:
# city       department
# Bangalore  Data Science    72862.000000
#            Engineering     79164.500000
#            Finance         67015.750000
#            Hr              67048.000000
#            Marketing       62080.666667
# Chennai    Engineering     73129.000000
#            Finance         71889.000000
#            Hr              49042.500000
#            Marketing       59354.750000
#            Sales           57858.000000
# Delhi      Data Science    76267.000000
#            Engineering     71663.750000
#            Finance         66422.000000
#            Hr              58917.600000
#            Marketing       62910.000000
#            Sales           66095.000000
# Hyderabad  Data Science    81502.333333
#            Engineering     76730.500000
#            Finance         69947.071429
#            Hr              58083.285714
#            Marketing       55663.400000
#            Sales           57669.125000
# Kolkata    Data Science    72303.000000
# ...

# %%
df.groupby("department").agg({
    "salary": ["mean", "max"],
    "performance_score": "mean",
    "employee_id": "count"
})
# Out:
#                     salary          performance_score employee_id
#                       mean      max              mean       count
# department
# Data Science  76450.800000  88216.0          5.700000          10
# Engineering   74038.205882  84870.0          5.705882          17
# Finance       66187.705882  80597.0          5.294118          17
# Hr            59524.875000  88366.0          5.708333          24
# Marketing     59382.000000  69499.0          5.894737          19
# Sales         59289.055556  68490.0          6.555556           9

# %%
department_summary = df.groupby("department").agg(
    average_salary=("salary", "mean"),
    highest_salary=("salary", "max"),
    employee_count=("employee_id", "count")
)

# %%
department_summary
# Out:
#               average_salary  highest_salary  employee_count
# department
# Data Science    76450.800000         88216.0              10
# Engineering     74038.205882         84870.0              17
# Finance         66187.705882         80597.0              17
# Hr              59524.875000         88366.0              24
# Marketing       59382.000000         69499.0              19
# Sales           59289.055556         68490.0               9

# %%
import pandas as pd
dummy=pd.Series([10,20,30,40])
dummy
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={"Name":["aman","riya","karan","sneha","nilesh"],
      "Age":[18,19,18,20,19],
      "Marks":[85,92,76,88,95]}
dummy_df=pd.DataFrame(data)
dummy_df.describe()
# Out:
#             Age      Marks
# count   5.00000   5.000000
# mean   18.80000  87.200000
# std     0.83666   7.328028
# min    18.00000  76.000000
# 25%    18.00000  85.000000
# 50%    19.00000  88.000000
# 75%    19.00000  92.000000
# max    20.00000  95.000000

# %%
dummy_df["Name"]
# Out:
# 0      aman
# 1      riya
# 2     karan
# 3     sneha
# 4    nilesh
# Name: Name, dtype: object

# %%
dummy_df[dummy_df["Marks"]>80]
# Out:
#      Name  Age  Marks
# 0    aman   18     85
# 1    riya   19     92
# 3   sneha   20     88
# 4  nilesh   19     95

# %%
dummy_df.iloc[:3]
# Out:
#     Name  Age  Marks
# 0   aman   18     85
# 1   riya   19     92
# 2  karan   18     76

# %%
dummy_df["Marks"].mean()
# Out:
# 87.2

# %%
dummy_df["Marks"].max()
dummy_df.loc[dummy_df["Marks"].idxmax()]
# Out:
# Name         nilesh
# Age              19
# Marks            95
# pass/fail      pass
# Name: 4, dtype: object

# %%
dummy_df["pass/fail"]=dummy_df["Marks"].apply(lambda x: "pass" if x>=40 else "fail")
dummy_df
# Out:
#      Name  Age  Marks pass/fail
# 0    aman   18     85      pass
# 1    riya   19     92      pass
# 2   karan   18     76      pass
# 3   sneha   20     88      pass
# 4  nilesh   19     95      pass

# %%
(dummy_df["Marks"]>90).sum()
# Out:
# 2

# %%
students_df = pd.DataFrame({
    "Name": ["Aman", "Riya", "Karan", "Sneha", "Nilesh"],
    "Marks": [85, 92, None, 88, 95]   # Notice the NaN
})

students_df["Marks"].fillna(students_df["Marks"].mean(), inplace=True)
print(students_df)
# Out:
#      Name  Marks
# 0    Aman   85.0
# 1    Riya   92.0
# 2   Karan   90.0
# 3   Sneha   88.0
# 4  Nilesh   95.0
# C:\Users\kashy\AppData\Local\Temp\ipykernel_32972\2072032255.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   students_df["Marks"].fillna(students_df["Marks"].mean(), inplace=True)
