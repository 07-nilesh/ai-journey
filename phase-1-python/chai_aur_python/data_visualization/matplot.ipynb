# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Matplotlib Basics

# %%
x= np.linspace(0,5,11)
y=x**2
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel("chacha")
plt.ylabel("chachi")
# Out:
# Text(0, 0.5, 'chachi')

# %% [markdown]
# Subplots

# %%
plt.subplot(2,2,1)
plt.plot(x,x**2)
plt.subplot(2,2,2)
plt.plot(x,x)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)

# %% [markdown]
# Object Oriented way
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches dpi is the dots-per-inch (pixel per inch).

# %%
fig=plt.figure(figsize=(6,10),dpi=100)
axis1=fig.add_axes([0.1,0.1,0.8,0.8])
axis1.plot(x,y)
axis2=fig.add_axes([0.1,0.1,0.7,0.7])
axis2.plot(x,y)

# %% [markdown]
# Types of plots

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([12., 10., 12., 10., 10., 11.,  4.,  9., 15.,  7.]),
#  array([ 16. , 113.7, 211.4, 309.1, 406.8, 504.5, 602.2, 699.9, 797.6,
#         895.3, 993. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26f3c1290d0>,
#   <matplotlib.lines.Line2D at 0x26f3c1293d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x26f3c1296d0>,
#   <matplotlib.lines.Line2D at 0x26f3c0e2b40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x26f3c128e90>],
#  'medians': [<matplotlib.lines.Line2D at 0x26f3c1297f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26f3c129af0>],
#  'means': []}

# %% [markdown]
# Saving Plots

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# Working With Images

# %%
import matplotlib.image as mpimp
img=mpimp.imread("linkedin_cover.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 1583.5, 395.5, -0.5)

# %%
cropped_img=img[50:100,100:300]
plt.imshow(cropped_img)

# %% [markdown]
# optional designing

# %%
xaxis=np.linspace(0,5,11)

# %%
fig,ax=plt.subplots(figsize=(12,6))

#Plotting Lines with Different Widths
ax.plot(xaxis,xaxis+1,color="red",linewidth=0.25)
ax.plot(xaxis,xaxis+2,color="red",linewidth=0.50)
ax.plot(xaxis,xaxis+3,color="red",linewidth=1.00)
ax.plot(xaxis,xaxis+4,color="red",linewidth=2.00)

#Different Line Styles
ax.plot(xaxis,xaxis+5,color="green",lw=3,linestyle="-")
ax.plot(xaxis,xaxis+6,color="green",lw=3,ls="-.")
ax.plot(xaxis,xaxis+7,color="green",lw=3,ls=":")

#Custom Dash Pattern
line,=ax.plot(xaxis,xaxis+8,color="black",lw=1.50)
line.set_dashes([5,50,15,50])

#Adding Markers
ax.plot(xaxis,xaxis+9, color="blue",lw=3,ls="-",marker="+",label="hii")
ax.plot(xaxis,xaxis+10, color="blue",lw=3,ls="--",marker="o")
ax.plot(xaxis,xaxis+11, color="blue",lw=3,ls="-",marker="s")
ax.plot(xaxis,xaxis+12, color="blue",lw=3,ls="--",marker="1")

#Marker Customization
ax.plot(xaxis,xaxis+13,color="purple",lw=1,ls="-",marker="o",markersize=2)
ax.plot(xaxis,xaxis+14,color="purple",lw=1,ls="-",marker="o",markersize=4)
ax.plot(xaxis,xaxis+15,color="purple",lw=1,ls="-",marker="o",markersize=8,markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")
ax.legend(loc="best")
