# %%
import numpy as np
z=np.arange(10)
np.add.reduce(z)
# Out:
# 45

# %%
import numpy as np
A=np.random.randint(0,2,5)
B=np.random.randint(0,2,5)
equal = np.allclose(A, B)
print(equal)
equal = np.array_equal(A, B)
print(equal)
# Out:
# False
# False

# %%
import numpy as np
z=np.zeros(10)
z.flags.writeable = False
z[0] = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 import numpy as np
#       2 z=np.zeros(10)
#       3 z.flags.writeable = False
# ----> 4 z[0] = 1
#
# ValueError: assignment destination is read-only

# %%
import numpy as np
z=np.random.random((10,2))
x,y=z[:,0],z[:,1]
R=np.sqrt(x**2+y**2)
T=np.arctan2(y,x)
print(R)
print(T)
# Out:
# [0.98134959 1.1764889  0.62136656 0.34152331 0.53362649 0.48633606
#  0.98432465 0.1268289  0.44816093 0.81275567]
# [0.8961832  0.89723302 0.50444644 1.22494525 0.85640909 0.48922203
#  0.35500781 0.58289272 1.02216688 1.41138292]
