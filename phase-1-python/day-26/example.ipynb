# %%
import pandas as pd

df_ipl = pd.read_csv('IPL.csv')
# Out:
# C:\Users\kashy\AppData\Local\Temp\ipykernel_15496\1431097025.py:3: DtypeWarning: Columns (0: review_batter, 1: team_reviewed, 2: review_decision, 3: umpire, 4: season, 5: superover_winner, 6: result_type, 7: method, 8: event_match_no) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ipl = pd.read_csv('IPL.csv')

# %%
# 1. See how massive the dataset is (Rows, Columns)
print(df_ipl.shape)

# 2. Look at the column names, data types, and check for missing values
df_ipl.info()

# 3. Look at a live snapshot of the first 5 rows to see what the data actually looks like
df_ipl.head()
# Out:
# (283678, 65)
# <class 'pandas.DataFrame'>
# RangeIndex: 283678 entries, 0 to 283677
# Data columns (total 65 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         283678 non-null  int64
#  1   match_id           283678 non-null  int64
#  2   date               283678 non-null  str
#  3   match_type         283678 non-null  str
#  4   event_name         283678 non-null  str
#  5   innings            283678 non-null  int64
#  6   batting_team       283678 non-null  str
#  7   bowling_team       283678 non-null  str
#  8   over               283678 non-null  int64
#  9   ball               283678 non-null  int64
#  10  ball_no            283678 non-null  float64
#  11  batter             283678 non-null  str
#  12  bat_pos            283678 non-null  int64
#  13  runs_batter        283678 non-null  int64
#  14  balls_faced        283678 non-null  int64
#  15  bowler             283678 non-null  str
# ...

# %%
heaviest_hitters=df_ipl['batting_team'].value_counts().head(10)
print(heaviest_hitters)
# Out:
# batting_team
# Mumbai Indians                 33892
# Kolkata Knight Riders          31398
# Chennai Super Kings            31027
# Rajasthan Royals               28430
# Royal Challengers Bangalore    28205
# Sunrisers Hyderabad            24078
# Kings XI Punjab                22646
# Delhi Daredevils               18786
# Delhi Capitals                 13100
# Punjab Kings                    9331
# Name: count, dtype: int64

# %%
unique_talents=df_ipl['batter'].nunique()
print(f"Unique Batters: {unique_talents}")
# Out:
# Unique Batters: 719

# %%
death_overs=df_ipl[df_ipl['over']==19]
print(death_overs.head())
# Out:
#      Unnamed: 0  match_id        date match_type             event_name  \
# 118      141725    335982  2008-04-18        T20  Indian Premier League
# 119      141726    335982  2008-04-18        T20  Indian Premier League
# 120      141727    335982  2008-04-18        T20  Indian Premier League
# 121      141728    335982  2008-04-18        T20  Indian Premier League
# 122      141729    335982  2008-04-18        T20  Indian Premier League
#
#      innings           batting_team                 bowling_team  over  ball  \
# 118        1  Kolkata Knight Riders  Royal Challengers Bangalore    19     1
# 119        1  Kolkata Knight Riders  Royal Challengers Bangalore    19     2
# 120        1  Kolkata Knight Riders  Royal Challengers Bangalore    19     3
# 121        1  Kolkata Knight Riders  Royal Challengers Bangalore    19     4
# 122        1  Kolkata Knight Riders  Royal Challengers Bangalore    19     5
#
# ...

# %%
position=df_ipl.iloc[10000]
print(f"Position of the 10,000th row: {position}")
# Out:
# Position of the 10,000th row: Unnamed: 0                             152065
# match_id                               336027
# date                               2008-05-20
# match_type                                T20
# event_name              Indian Premier League
#                               ...
# batter_balls                                1
# bowler_wicket                               0
# batting_partners    ('AB Agarkar', 'WP Saha')
# next_batter                               NaN
# striker_out                             False
# Name: 10000, Length: 65, dtype: object

# %%
targeted_query=df_ipl.query('batting_team == "Chennai Super Kings" and runs_total ==6')
print(targeted_query.head())
# Out:
#      Unnamed: 0  match_id        date match_type             event_name  \
# 258      141865    335983  2008-04-19        T20  Indian Premier League
# 273      141880    335983  2008-04-19        T20  Indian Premier League
# 279      141886    335983  2008-04-19        T20  Indian Premier League
# 287      141894    335983  2008-04-19        T20  Indian Premier League
# 291      141898    335983  2008-04-19        T20  Indian Premier League
#
#      innings         batting_team     bowling_team  over  ball  ...  \
# 258        1  Chennai Super Kings  Kings XI Punjab     5     2  ...
# 273        1  Chennai Super Kings  Kings XI Punjab     7     5  ...
# 279        1  Chennai Super Kings  Kings XI Punjab     8     5  ...
# 287        1  Chennai Super Kings  Kings XI Punjab    10     1  ...
# 291        1  Chennai Super Kings  Kings XI Punjab    10     5  ...
#
#      team_balls team_wicket  new_batter  power_surge_start  batter_runs  \
# ...
